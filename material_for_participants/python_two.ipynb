# %% [markdown]
# # Reviewing Day 1

# %%
1 + 1
# Out:
# 2

# %%
i = 10

# %%
f = 10.3

# %%
f
# Out:
# 10.3

# %%
s = 'strings'

# %%
s
# Out:
# 'strings'

# %%
s[3]
# Out:
# 'i'

# %%
s[:4]
# Out:
# 'stri'

# %%
s[2:]
# Out:
# 'rings'

# %%
s[-2]
# Out:
# 'g'

# %%
li = [1, 2, 3, 4]

# %%
li
# Out:
# [1, 2, 3, 4]

# %%
for index in li:
    print(index)
# Out:
# 1
# 2
# 3
# 4

# %%
len(li)
# Out:
# 4

# %%
import numpy as np

# %%
data = np.loadtxt(fname='data/inflammation-01.csv',
